# %% [markdown]
# ### MNIST - model

# %%
# !pip3 install visualkeras
# Out:
# ...
#      |████████████████████████████████| 994 kB 3.6 MB/s eta 0:00:01
# ...

# %%
from tensorflow.python.keras.layers import Dense, Conv2D, Flatten, Dropout, MaxPooling2D, ZeroPadding2D
from collections import defaultdict

color_map = defaultdict(dict)
color_map[Conv2D]['fill'] = 'orange'
color_map[ZeroPadding2D]['fill'] = 'gray'
color_map[Dropout]['fill'] = 'pink'
color_map[MaxPooling2D]['fill'] = 'red'
color_map[Dense]['fill'] = 'green'
color_map[Flatten]['fill'] = 'teal'

visualkeras.layered_view(model, color_map=color_map)
# Out:
# <PIL.Image.Image image mode=RGBA size=636x139 at 0x7FCD55DA2250>

# %%
import sys
sys.path.append('../..')
import visualkeras
import utils.models.mnist_model as Model

model_gen = Model.MNISTModel()
model = model_gen.get_mnist_model()


visualkeras.layered_view(model, legend=True, to_file='./model_architecture/MNISTModel.png')  # font is optional!
# Out:
# <PIL.Image.Image image mode=RGBA size=636x175 at 0x7FCD690A6F70>

# %% [markdown]
# ### Embryo

# %%
import sys
sys.path.append('../..')
import visualkeras
import utils.models.vitrolife_model as Model

model_gen = Model.VitroLifeModel()
model = model_gen.get_low_GPU_mem_model_batchnorm()


visualkeras.layered_view(model, legend=True, to_file='./model_architecture/Embryo.png')  # font is optional!
# Out:
# <PIL.Image.Image image mode=RGBA size=805x426 at 0x7FCD6836D790>
